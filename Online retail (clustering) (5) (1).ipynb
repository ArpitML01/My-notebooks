# %% [markdown]
# # Steps for creating and ideal  notebook (subject to change)

# %% [markdown]
# # 1. Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Importing dataset

# %%
df = pd.read_excel(r"C:\Users\LENOVO\Desktop\online_retail_II.xlsx")

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %% [markdown]
# # 3. Data Inspection

# %% [markdown]
# 3.a. Check rows (top and bottom)

# %%
df.head(10)
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# 5  489434     22064           PINK DOUGHNUT TRINKET POT         24
# 6  489434     21871                  SAVE THE PLANET MUG        24
# 7  489434     21523   FANCY FONT HOME SWEET HOME DOORMAT        10
# 8  489435     22350                            CAT BOWL         12
# 9  489435     22349       DOG BOWL , CHASING BALL DESIGN        12
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# ...

# %%
df.tail(10)
# Out:
#        Invoice StockCode                         Description  Quantity  \
# 525451  538171     22748           POPPY'S PLAYHOUSE KITCHEN         2
# 525452  538171     22745          POPPY'S PLAYHOUSE BEDROOM          2
# 525453  538171     22558     CLOTHES PEGS RETROSPOT PACK 24          4
# 525454  538171     21671        RED SPOT CERAMIC DRAWER KNOB         6
# 525455  538171     20971    PINK BLUE FELT CRAFT TRINKET BOX         2
# 525456  538171     22271                FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750        FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751      FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970  PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931              JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# 525451 2010-12-09 20:01:00   2.10      17530.0  United Kingdom
# ...

# %% [markdown]
# 3.b. check total number of rows and shape also columns (length, shape, columns)

# %%
len(df)
# Out:
# 525461

# %%
df.shape
# Out:
# (525461, 8)

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %% [markdown]
# 3.c. Check non null and data types

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    107927
# Country             0
# dtype: int64

# %% [markdown]
# 3.d. Check descriptive stats

# %%
df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  525461.000000                         525461  525461.000000
# mean       10.337667  2010-06-28 11:37:36.845017856       4.688834
# min     -9600.000000            2009-12-01 07:45:00  -53594.360000
# 25%         1.000000            2010-03-21 12:20:00       1.250000
# 50%         3.000000            2010-07-06 09:51:00       2.100000
# 75%        10.000000            2010-10-15 12:45:00       4.210000
# max     19152.000000            2010-12-09 20:01:00   25111.090000
# std       107.424110                            NaN     146.126914
#
#          Customer ID
# count  417534.000000
# mean    15360.645478
# min     12346.000000
# 25%     13983.000000
# 50%     15311.000000
# 75%     16799.000000
# max     18287.000000
# std      1680.811316

# %% [markdown]
# 3.f. Check outliers

# %% [markdown]
# 3.g.Determine the target variable and What is your objective  (the target variable shall decide wether the Model will be regression, classification or clustering)

# %% [markdown]
# # 4. Data Preparation (Transformation)

# %% [markdown]
# 4.a. Missing values(Handling and Impute)(Topic to be prepared )

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
df1 = df.dropna()

# %%
df1
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %% [markdown]
# ### Extracting R(Recency), F(freuqency), M(Monetary) columns from the data that we imported in

# %%
# extracting amount by multiplying quantity and price 
amount = pd.DataFrame(df1.Quantity * df1.Price, columns = ["Amount"])
amount.head()
# Out:
#    Amount
# 0    83.4
# 1    81.0
# 2    81.0
# 3   100.8
# 4    30.0

# %%
df1 = pd.concat(objs = [df1, amount], axis =1, ignore_index = False)

# %%
df1
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country  Amount
# ...

# %%
df1.shape
# Out:
# (417534, 9)

# %%
monetary = df1.groupby("Customer ID").Amount.sum()
monetary = monetary.reset_index()
monetary.head()
# Out:
#    Customer ID   Amount
# 0      12346.0   -64.68
# 1      12347.0  1323.32
# 2      12348.0   222.16
# 3      12349.0  2646.99
# 4      12351.0   300.93

# %% [markdown]
# # Frequency

# %%
frequency = df1[['Customer ID', 'InvoiceDate']]

# %%
#Getting the count of orders made by each customer based on customer ID.
k = frequency.groupby("Customer ID").InvoiceDate.count()
k = pd.DataFrame(k)
k = k.reset_index()
k.columns = ["Customer ID", "Frequency"]
k.head()
# Out:
#    Customer ID  Frequency
# 0      12346.0         46
# 1      12347.0         71
# 2      12348.0         20
# 3      12349.0        107
# 4      12351.0         21

# %%
master = monetary.merge(k, on="Customer ID", how ="inner")

# %%
master.head()
# Out:
#    Customer ID   Amount  Frequency
# 0      12346.0   -64.68         46
# 1      12347.0  1323.32         71
# 2      12348.0   222.16         20
# 3      12349.0  2646.99        107
# 4      12351.0   300.93         21

# %% [markdown]
# # Recency

# %%
recency = df1[["Customer ID", "InvoiceDate"]]
#finding max data
maximum = max (recency.InvoiceDate)
recency['maximum'] = max(recency.InvoiceDate)
# adding one more day to the max data, so that the max will have 1 as the differenece and not zero.
maximum = maximum + pd.DateOffset (days=1)
recency['Diff']= maximum - recency.InvoiceDate
recency.head()
# Out:
#    Customer ID         InvoiceDate             maximum              Diff
# 0      13085.0 2009-12-01 07:45:00 2010-12-09 20:01:00 374 days 12:16:00
# 1      13085.0 2009-12-01 07:45:00 2010-12-09 20:01:00 374 days 12:16:00
# 2      13085.0 2009-12-01 07:45:00 2010-12-09 20:01:00 374 days 12:16:00
# 3      13085.0 2009-12-01 07:45:00 2010-12-09 20:01:00 374 days 12:16:00
# 4      13085.0 2009-12-01 07:45:00 2010-12-09 20:01:00 374 days 12:16:00

# %%
# recency by customerID
a = recency.groupby('Customer ID')

# %%
a.Diff.min()
# Out:
# Customer ID
# 12346.0    67 days 03:28:00
# 12347.0     3 days 05:04:00
# 12348.0    74 days 05:02:00
# 12349.0    43 days 11:38:00
# 12351.0    11 days 04:38:00
#                  ...
# 18283.0    18 days 04:31:00
# 18284.0    65 days 07:30:00
# 18285.0   296 days 09:37:00
# 18286.0   112 days 08:04:00
# 18287.0    18 days 08:10:00
# Name: Diff, Length: 4383, dtype: timedelta64[ns]

# %%
#Dataframe merging by recency 
df = pd.DataFrame(recency.groupby('Customer ID').Diff.min())
df = df.reset_index()
df.columns = ["Customer ID", "Recency"]
df.head()
# Out:
#    Customer ID          Recency
# 0      12346.0 67 days 03:28:00
# 1      12347.0  3 days 05:04:00
# 2      12348.0 74 days 05:02:00
# 3      12349.0 43 days 11:38:00
# 4      12351.0 11 days 04:38:00

# %% [markdown]
# # RFM combined database

# %%
#combining all recency, frequency and monetary parameters
RFM = pd.merge(left = df, right = master, on= 'Customer ID')

# %%
RFM
# Out:
#       Customer ID           Recency   Amount  Frequency
# 0         12346.0  67 days 03:28:00   -64.68         46
# 1         12347.0   3 days 05:04:00  1323.32         71
# 2         12348.0  74 days 05:02:00   222.16         20
# 3         12349.0  43 days 11:38:00  2646.99        107
# 4         12351.0  11 days 04:38:00   300.93         21
# ...           ...               ...      ...        ...
# 4378      18283.0  18 days 04:31:00   641.77        230
# 4379      18284.0  65 days 07:30:00   436.68         29
# 4380      18285.0 296 days 09:37:00   427.00         12
# 4381      18286.0 112 days 08:04:00  1188.43         70
# 4382      18287.0  18 days 08:10:00  2340.61         86
#
# [4383 rows x 4 columns]

# %% [markdown]
# # Outlier Treatment

# %%
#outlier treatent for amount
plt.boxplot(RFM.Amount)
Q1 = RFM.Amount.quantile(0.25)
Q3 = RFM.Amount.quantile(0.75)
IQR = Q3 - Q1
RFM = RFM [(RFM.Amount >=Q1 - 1.5 *IQR) & (RFM.Amount <=Q3 + 1.5*IQR)]

# %%
# Outlier treatment for Frequency
plt.boxplot(RFM.Frequency)
Q1 = RFM.Frequency.quantile(0.25)
Q3 = RFM.Frequency.quantile(0.75)
IQR = Q3 - Q1
RFM = RFM [(RFM.Frequency >=Q1 - 1.5 *IQR) & (RFM.Frequency <=Q3 + 1.5*IQR)]

# %%
# Outlier treatment for Recency 
plt.boxplot(RFM.Recency)
Q1 = RFM.Recency.quantile(0.25)
Q3 = RFM.Recency.quantile(0.75)
IQR = Q3 - Q1
RFM = RFM [(RFM.Recency >=Q1 - 1.5 *IQR) & (RFM.Recency <=Q3 + 1.5*IQR)]

# %%
RFM.head(20)
# Out:
#     Customer ID           Recency   Amount  Frequency
# 0       12346.0  67 days 03:28:00   -64.68         46
# 1       12347.0   3 days 05:04:00  1323.32         71
# 2       12348.0  74 days 05:02:00   222.16         20
# 3       12349.0  43 days 11:38:00  2646.99        107
# 4       12351.0  11 days 04:38:00   300.93         21
# 5       12352.0  11 days 09:54:00   343.80         18
# 6       12353.0  44 days 07:17:00   317.76         20
# 7       12355.0 203 days 08:02:00   488.21         22
# 8       12356.0  16 days 07:37:00  3562.25         84
# 10      12358.0  11 days 09:05:00  2719.01         58
# 11      12359.0  61 days 08:45:00  2469.36        121
# 12      12360.0  15 days 08:57:00  1550.83         89
# 13      12361.0  98 days 04:42:00   321.35         19
# 14      12362.0 374 days 09:51:00   130.00          1
# 15      12366.0 269 days 09:33:00   500.24          3
# 16      12368.0 264 days 04:05:00   917.70         18
# ...

# %%
RFM.shape
# Out:
# (3674, 4)

# %% [markdown]
# 5.a. Start with looking at columns (make sure you understand the context with the target variable of each column)

# %% [markdown]
# 5.b Classify analysis in term of univariate, bivariate, multivariate analysis (all of your charts/ vis/graphs ) will fall under these categories)

# %% [markdown]
# 5.c. Start asking relevant question and draft them as well

# %% [markdown]
# 5.d. Start answering these questions with relevant visuals

# %% [markdown]
# 5.e. Pick visual such as - Histogram, Pairplot (only if variable are less), Bar chart, Pie chart, Pivot tables, Scatter plot, box plot, heat map (correlation matrix), violin plot, bubble chart, line chart

# %% [markdown]
# 5.f. Start writing Interpretations on chart , as much descriptive and simple in language as possible

# %% [markdown]
# 6.a. Check for multicollinearity through VIF (variance inflation factor)

# %% [markdown]
# 6.b. Check for non-correlated variables through Heat matrix or also through Code for high correlation matrix

# %% [markdown]
# 6.c. If going for linear models then check for linearity (scatter plot and check linear pattern)

# %% [markdown]
# 6.d. Feature ranking through REcursive feature elimination (RFE)

# %% [markdown]
# 6.e. Business context for fetures

# %% [markdown]
# 6.f. Generic approach to reduce variables (top down or bottoms up approach)

# %% [markdown]
# 7.a  X -->Everything in the data except target variable

# %% [markdown]
# 7.b. y----> Just the target variable

# %% [markdown]
# 7.c Make sure both these are dataframe and not series, ensure shape is 2D

# %% [markdown]
# #8.a. Import train test split from sklearn (model_selection)

# %% [markdown]
# 8.b. Copy the train test split code from doc string (? sign)

# %% [markdown]
# 8.c  Ensure the testing/training percentage is proper and random variable is set same for same experiment results

# %% [markdown]
# # 9.Scaling

# %% [markdown]
# # standarsise all parameters

# %%
#RFM_norm1 = RFM.drop("Customer ID",axis =1)

# %%
#RFM_norm1.Recency =RFM_normal.Recency.dt.days

# %%
#from sklearn.preprocessing import StandardScaler

# %%
##standard_scaler = StandardScaler()

# %%
#RFM_norm1= standard_scaler.fit_transform(RFM_norm1)
#RFM_norm1 = standard_scaler.fit_transform(RFM_norm1)
RFM_norm1 = RFM.drop("Customer ID",axis=1)
RFM_norm1.Recency = RFM_norm1.Recency.dt.days

from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()
RFM_norm1 = standard_scaler.fit_transform(RFM_norm1)

# %%
RFM_norm1 = pd.DataFrame(RFM_norm1)
RFM_norm1.columns = ['Recency','Amount','Frequency']
RFM_norm1.head()
# Out:
#     Recency    Amount  Frequency
# 0 -0.353197 -1.107635  -0.050075
# 1 -0.985113  0.720052   0.531607
# 2 -0.284082 -0.729931  -0.655024
# 3 -0.590166  2.463032   1.369229
# 4 -0.906123 -0.626208  -0.631756

# %% [markdown]
# # K means with some k

# %%
# kmeans with k=5

# %%
from sklearn.cluster import KMeans
model_clus5 = KMeans(n_clusters = 5, max_iter=50)

# %%
model_clus5 = KMeans(n_clusters = 5, max_iter=50)

# %%
model_clus5.fit(RFM_norm1)
# Out:
# KMeans(max_iter=50, n_clusters=5)

# %%
model_clus5.labels_
# Out:
# array([2, 1, 2, ..., 3, 1, 4])

# %% [markdown]
# # Silhouette Analysis

# %%
from sklearn.metrics import silhouette_score
sse_ = []
for k in range(2, 15):
    kmeans = KMeans(n_clusters=k).fit(RFM_norm1)
    sse_.append([k, silhouette_score(RFM_norm1, kmeans.labels_)])

# %%
sse_
# Out:
# [[2, 0.4257961899335694],
#  [3, 0.43612474090717923],
#  [4, 0.40055376702464685],
#  [5, 0.4004080159069716],
#  [6, 0.35582149176799144],
#  [7, 0.327317091536102],
#  [8, 0.33124771209153586],
#  [9, 0.31812423684307545],
#  [10, 0.3089768016604],
#  [11, 0.3194009300130362],
#  [12, 0.2989941889791003],
#  [13, 0.30951083648498057],
#  [14, 0.3077286834813754]]

# %%
plt.plot(pd.DataFrame(sse_)[0], pd.DataFrame(sse_)[1]);

# %% [markdown]
# # WCSS Clustering

# %%
from sklearn.cluster import KMeans
#calculate WCSS for different values of K
wcss = []
for k in range (1,11):
    kmeans = KMeans(n_clusters =k, init ='k-means++', random_state = 42)
    kmeans.fit(RFM_norm1)
    wcss.append(kmeans.inertia_)   #Inertia is the same as WCSS

# %%
#Plotting the Elbow Curve
plt.figure(figsize = (8, 5))
plt.plot(range (1,11), wcss, marker= 'o', linestyle ='--')
plt.title('Elbow Curve for Optimal K')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS (Within- Cluster Sum of Squares)')
plt.grid(True)
plt.show()

# %%
# analysis  of clusters formed
RFM.index = pd.RangeIndex(len(RFM.index))

# %%
RFM_km = pd.concat([RFM,pd.Series(model_clus5.labels_)],axis=1)

# %%
RFM_km.columns = ['Customer ID','Recency','Amount','Frequency','ClusterID']

# %%
RFM_km

# %%
#RFM_km.Recency = RFM_km.Recency.dt.days
RFM_km.Recency = RFM_km.Recency.dt.days

# %%
km_clusters_amount = pd.DataFrame(RFM_km.groupby(['ClusterID']).Amount.mean())

# %%
km_clusters_frequency = pd.DataFrame(RFM_km.groupby(["ClusterID"]).Frequency.mean())

# %%
km_clusters_receny = pd.DataFrame(RFM_km.groupby(["ClusterID"]).Recency.mean())

# %%
df = pd.concat([pd.Series([0,1,2,3,4]),km_clusters_amount,km_clusters_frequency,km_clusters_receny],axis =1)

# %%
df.columns = ["ClusterID","Amount_mean","Frequency_mean","Recency_mean"]

# %%
df.head()

# %%
sns.barplot(x=df.ClusterID, y=df.Amount_mean)

# %%
sns.barplot(x=df.ClusterID, y=df.Frequency_mean)

# %%
sns.barplot(x=df.ClusterID, y=df.Recency_mean)

# %% [markdown]
# # 10. Model fitting

# %% [markdown]
# 10.a Choose appropriate algorithm, download and put it in a variable

# %% [markdown]
# 10.b fit X train, y_train with this model

# %% [markdown]
# 10.c perdict on Xtest and assign it to y_pred ---> A new Variable (not applicable in clustering)

# %% [markdown]
# # 11. Model evaluation

# %% [markdown]
# 11.a. Choose right metrics, for regression metric are different than classifictaion (very different in Clustering)

# %% [markdown]
# 11.b Compare between y_test and y_pred and evaluate final score

# %% [markdown]
# 11.c. Do this for multiple algorithm and and then compare score
